# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/My Drive/yolo_implementation'
# Out:
# ajith.zip  chart.png		    custom_weight  darknet53.conv.74  elon.zip
# backup	   chart_yolov3_custom.png  darknet	   elon

# %%
# !unzip '/content/drive/My Drive/yolo_implementation/ajith.zip' -d '/content/drive/My Drive/yolo_implementation'
# Out:
# Archive:  /content/drive/My Drive/yolo_implementation/ajith.zip
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a1.jpg
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a1.txt
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a10.jpg
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a10.txt
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a11.jpg
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a11.txt
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a12.jpg
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a12.txt
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a13.jpg
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a13.txt
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a14.jpg
#   inflating: /content/drive/My Drive/yolo_implementation/ajith/a14.txt
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/yolo_implementation/darknet'
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# Cloning into '/content/drive/My Drive/yolo_implementation/darknet'...
# fatal: Unable to read current working directory: No such file or directory

# %%
# %cd /content/drive/My Drive/yolo_implementation/darknet
# Out:
# /content/drive/My Drive/yolo_implementation/darknet

# %%
ls
# Out:
# 3rdparty/               docker-compose.yml     package.xml
# build/                  Dockerfile.cpu         README.md
# build.ps1               Dockerfile.gpu         results/
# cfg/                    image_yolov3.sh        scripts/
# cmake/                  image_yolov4.sh        src/
# CMakeLists.txt          include/               vcpkg.json
# DarknetConfig.cmake.in  json_mjpeg_streams.sh  vcpkg.json.opencv23
# darknet_images.py       LICENSE                video_yolov3.sh
# darknet.py              Makefile               video_yolov4.sh
# darknet_video.py        net_cam_v3.sh
# data/                   net_cam_v4.sh

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1444:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1444 |         char buff[100];
#       |              ^~~~
# ...

# %%
# %cd /content/drive/My Drive/yolo_implementation
# Out:
# /content/drive/My Drive/yolo_implementation

# %%
# !python ajith/creating-files-data-and-name.py

# %%
# !python ajith/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet detector train ajith/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# /bin/bash: line 1: darknet/darknet: Permission denied

# %%
# !chmod +x ./darknet

# %%
# !darknet/darknet detector train elon/labelled_data.data darknet/cfg/yolov2_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# /bin/bash: line 1: darknet/darknet: Not a directory
